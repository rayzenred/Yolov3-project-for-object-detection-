# %%
# !nvidia-smi
# Out:
# Mon Dec 20 11:36:15 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# '2021_07_27 4_21 pm Office Lens.jpg'  'lor Hod.docx'
#  adi1.pptx			      'Meet Recordings'
# 'batch 28.pptx'			      'ML assignment-1 18131A0583.pdf'
# 'CandidateHallTicket (1).pdf'	       MS
# 'CC Assignment(18131A0583).gdoc'      'MS Resume.docx'
#  certificate.pdf		      'MS Resume.pdf'
#  CERTI.pdf			      'My Drive'
#  Classroom			      'My Portfolio.pdf'
# 'Colab Notebooks'		      'Project proposal.gdoc'
# 'CRYPTO ARTICLE.docx'		       Resume.gdoc
#  IMG_20211129_101424.jpg	       screenshots.pdf
# 'Johnson Resume. (1).gdoc'	       SOP.gdoc
# 'Johnson Resume..gdoc'		       yolov4

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15379, done.
# remote: Total 15379 (delta 0), reused 0 (delta 0), pack-reused 15379
# Receiving objects: 100% (15379/15379), 14.01 MiB | 17.04 MiB/s, done.
# Resolving deltas: 100% (10341/10341), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# Out:
# /content/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !cp cfg/yolov3.cfg cfg/yolov4_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov4_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=32/' cfg/yolov4_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 8000/' cfg/yolov4_training.cfg
# !sed -i '610 s@classes=80@classes=4@' cfg/yolov4_training.cfg
# !sed -i '696 s@classes=80@classes=4@' cfg/yolov4_training.cfg
# !sed -i '783 s@classes=80@classes=4@' cfg/yolov4_training.cfg
# !sed -i '603 s@filters=255@filters=27@' cfg/yolov4_training.cfg
# !sed -i '689 s@filters=255@filters=27@' cfg/yolov4_training.cfg
# !sed -i '776 s@filters=255@filters=27@' cfg/yolov4_training.cfg

# %%
# !echo -e 'person\ndog\ncar\nbus' > data/obj.names
# !echo -e 'classes= 4\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov4' > data/obj.data

# %%
# !cp cfg/yolov4_training.cfg /mydrive/yolov4/yolov4_testing.cfg

# !cp data/obj.names /mydrive/yolov4/classes.txt

# %%
# !mkdir data/obj
# !unzip /mydrive/yolov4/images.zip -d data/obj
# Out:
# Archive:  /mydrive/yolov4/images.zip
#    creating: data/obj/images/
#   inflating: data/obj/images/00005e7429a94ad4.jpg
#   inflating: data/obj/images/00005e7429a94ad4.txt
#   inflating: data/obj/images/00013f14dd4e168f.jpg
#   inflating: data/obj/images/00013f14dd4e168f.txt
#   inflating: data/obj/images/0001c8c65851276f.jpg
#   inflating: data/obj/images/0001c8c65851276f.txt
#   inflating: data/obj/images/000346a7939c398c.jpg
#   inflating: data/obj/images/000346a7939c398c.txt
#   inflating: data/obj/images/00043e7c5c4c025a.jpg
#   inflating: data/obj/images/00043e7c5c4c025a.txt
#   inflating: data/obj/images/0004d5a9dd44ab6a.jpg
#   inflating: data/obj/images/0004d5a9dd44ab6a.txt
#   inflating: data/obj/images/0007eeeabf3c5e5c.jpg
#   inflating: data/obj/images/0007eeeabf3c5e5c.txt
#   inflating: data/obj/images/0009450a8ed12bd4 (2).jpg
#   inflating: data/obj/images/0009450a8ed12bd4 (2).txt
#   inflating: data/obj/images/0009450a8ed12bd4.jpg
# ...

# %%
import glob
images_list = glob.glob("data/obj/images/*.jpg")
with open("data/train.txt", "w") as f:
    f.write("\n".join(images_list))

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-12-20 11:38:50--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  53.7MB/s    in 2.9s
#
# 2021-12-20 11:38:53 (53.7 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !./darknet detector train data/obj.data cfg/yolov4_training.cfg darknet53.conv.74 -dont_show

# %%
# !./darknet detector train data/obj.data cfg/yolov4_training.cfg /mydrive/yolov4/yolov4_training_last.weights -dont_show
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# yolov4_training
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 2, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
